# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_parquet('/content/drive/MyDrive/Elective_Groups/Capstone/transactions_dataset.parquet',columns= ['date_order',
                                                              'product_id',
                                                              'client_id',
                                                              'sales_net',
                                                              'quantity',
                                                              'order_channel',
                                                              'branch_id'])
df.info()

# %%
df['month'] = df['date_order'].dt.strftime('%Y-%m')
df.head()

# %%
df.to_parquet('/content/drive/MyDrive/Elective_Groups/Capstone/Step_1_transactions_dataset_month.parquet')
